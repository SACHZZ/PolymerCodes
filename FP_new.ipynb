# %% [markdown]
# # ECFP6 Bits

# %%
import pandas as pd
import numpy as np

from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import AllChem
from rdkit.Chem import rdFingerprintGenerator
from rdkit import DataStructs
from rdkit.Chem import MACCSkeys
from rdkit.Chem.Fingerprints import FingerprintMols

# %%
df1 = pd.read_csv('bandgap_crystal_optimized.csv')

# %%
PandasTools.AddMoleculeColumnToFrame(df1,smilesCol='smiles')

# %%
df_ECFP6 = [AllChem.GetMorganFingerprintAsBitVect(x,3) for x in df1['ROMol']]

# %%
data_ecfp6_lists = [list(l) for l in df_ECFP6]

# %%
ecfp6_name = [f'Bit_{i}' for i in range(2048)]

# %%
data_ecfp6_df = pd.DataFrame(data_ecfp6_lists, columns=ecfp6_name)

# %%
data_ecfp6_df.shape
# Out:
# (236, 2048)

# %%
#data_ecfp6_df.to_csv('data_ecfp6_bits_crystal.csv')

# %% [markdown]
# # MACCS keys

# %%
df_maccs = [MACCSkeys.GenMACCSKeys(x) for x in df1['ROMol']]

# %%
df_maccs_lists = [list(l) for l in df_maccs]

# %%
maccs_name = [f'Bit_{i}' for i in range(167)]

# %%
data_maccs_df = pd.DataFrame(df_maccs_lists, columns=maccs_name)

# %%
data_maccs_df.shape
# Out:
# (236, 167)

# %%
#data_maccs_df.to_csv('data_maccs_crystal.csv')
